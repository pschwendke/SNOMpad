# %%
import numpy as np
import matplotlib.pyplot as plt
from styles import presentation

# %%
# %matplotlib notebook
presentation()

# %%
dat = np.load("trions.npy")

# %%
dat.shape
# Out:
# (1437421, 3)

# %%
plt.plot(dat)
# Out:
# <img src="data:image/png;base64,..." width="480">
# ...
